# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""

for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# shafquat.shayan@gmail.com
# www.linkedin.com/in/shayan-
# shafquat (LinkedIn)
# shayanshafquat.github.io/
# (Personal)
# Top Skills
# Artificial Intelligence (AI)
# Terraform
# AWS Lambda
# Certifications
# Data Science and Analytics using R
# programming
# AWS Lambda Foundations
# Amazon Web Services Cloud
# Practitioner
# Prediction and Control with Function
# Approximation
# Terraform for AWS - Beginner to
# Expert
# Shayan Shafquat
# GenAI @ Allstate | RL | Cognitive Neuroscience
# London, England, United Kingdom
# Summary
# I am a Senior Data Scientist with 2.5+ years of experience
# specializing in fine-grained pattern recognition, engineering LLM
# security solutions, and deploying AI (GenAI & Classical ML)
# approaches across insurance, transportation, and e-commerce
# industries. My foundation in Applied Mathematics and Computational
# Neuroscience has enabled me to contribute to projects at the
# intersection of AI and decision neuroscience.
# Currently, I focus on developing LLM-based applications, leveraging
# multi-agent systems and RAG frameworks to optimize workflows
# and improve AI security. At Allstate, I design and manage Lambda-
# triggered infrastructure for real-time data processing and enhance
# LLM-powered systems with advanced evaluation frameworks and
# contextual grounding using Guardrails.
# My technical expertise spans machine learning (multi-pass LLM
# frameworks, RAG systems, deep learning in NLP, CV, RL),
# responsible AI practices, and cloud infrastructure, including AWS
# services (Lambda, S3, Bedrock, SageMaker) and serverless
# architecture. I also specialize in backend development, including
# FastAPI/Flask API development, system architecture design, and
# Docker containerization.
# With proven business impact, including a 5% increase in cashless
# rides and improvements in conversion prediction and loss capture
# rates, I am committed to pushing the boundaries of AI-powered
# applications and building robust security measures to defend against
# prompt injection and adversarial attacks.
# Notably, I have worked on Neural Dynamics and Disease Modeling,
# where I simulated Alzheimer’s disease progression and explored
# neural stability during NREM sleep. I’ve also contributed to
# converting large-scale cortical models, ensuring compatibility and
# accuracy in simulating brain networks.
#   Page 1 of 3
# Experience
# Allstate
# Senior Data Scientist
# January 2025 - Present (7 months)
# Northern Ireland, United Kingdom
# Enkrypt AI
# AI Research Consultant
# June 2023 - September 2023 (4 months)
# • Developed a malicious file scanner for python scripts and jupyter notebooks
# to enhance ML lifecycle security.
# • Built a dataset for prompt injection and backdoor attacks to fine-tune LLMs
# for adversarial robustness.
# • Implemented demo-ready LLM security using RAGAS and NeMo GuardRails
# to counter toxicity, bias, and jailbreaks.
# Google Summer of Code
# Open source, cross simulator, large scale cortical models in NeuroML
# June 2022 - September 2022 (4 months)
# • Translated Layer 5 pyramidal cell properties to NeuroML, ensuring model
# accuracy.
# • Implemented GitHub Actions for maintaining model integrity in development.
# • Collaborated with experts to adhere to computational neuroscience standards
# for reproducible simulations.
# Ola
# Data Scientist I
# September 2020 - January 2022 (1 year 5 months)
# Bengaluru, Karnataka, India
# Led the development of a user identification system at Ola, increasing
# cashless ride transactions by 5%. Improved peak pricing accuracy by 2.2%
# and automated user-level pricing during COVID-19. Collaborated to enhance
# in-house data preprocessing utilities for AWS S3 retrieval.
# Ola (ANI Technologies Pvt. Ltd)
# Internship (Research Engineer)
# May 2019 - July 2019 (3 months)
# Bangalore
#   Page 2 of 3
# • Engineered features from partner ride data to predict login hours, optimizing
# incentive strategies.
# • Conducted A/B testing to validate incentive optimization effectiveness across
# multiple cities.
# Prof. Sameer Mathur, IIM Lucknow
# Intern (Data Analytics with Managerial Applications)
# May 2017 - June 2017 (2 months)
# • Completed the internship under the guidance of Prof. Sameer Mathur
# (Professor, Indian Institute of Management (IIM), Lucknow)
# • Learnt Regression Modelling, Ordinary Least Squares(OLS), various tests for
# hypothesis verification and Inferential Statistics.
# • Got introduced and mastered the concepts of R programming language
# Education
# University of Nottingham
# Master of Science - MS, Computational Neuroscience, Cognition and
# AI · (September 2023 - December 2024)
# Indian Institute of Technology, Kharagpur
# Integrated Msc, Mathematics and Computing · (2015 - 2020)
#   Page 3 of 3

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Shayan Shafquat"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Shayan Shafquat. You are answering questions on Shayan Shafquat's website, particularly questions related to Shayan Shafquat's career, background, skills and experience. Your responsibility is to represent Shayan Shafquat for interactions on the website as faithfully as possible. You are given a summary of Shayan Shafquat's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nI am a Senior Data Scientist with almost 3 years of experience specializing in fine-grained pattern recognition, engineering LLM security solutions, and deploying AI (GenAI & Classical ML) approaches across insurance, transportation, and e-commerce industries. My foundation in Applied Mathematics and Computational Neuroscience has enabled me to contribute to projects at the intersection of AI and decision neuroscience.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nshafquat.shayan@gmail.com\nwww.linkedin.com/in/shayan-\nshafquat (LinkedIn)\nshayanshafquat.github.io/\n(Personal)\nTop Skills\nArtificial Intelligence (AI)\nTerraform\nAWS Lambda\nCertifications\nData Science and Analytics using R\nprogramming\nAWS Lambda Foundations\nAmazon Web Services Cloud\nPractitioner\nPrediction and Control with Function\nApproximation\nTerraform for AWS - Beginner to\nExpert\nShayan Shafquat\nGenAI @ Allstate | RL | Cognitive Neuroscience\nLondon, England, United Kingdom\nSummary\nI am a Senior Data Scientist with 2.5+ years of experience\nspecializing in fine-grained pattern recognition, engineering LLM\nsecurity solutions, and deploying AI (GenAI & Classical ML)\napproaches across insurance, transportation, and e-commerce\nindustries. My foundation in Applied Mathematics and Computational\nNeuroscience has enabled me to contribute to projects at the\nintersection of AI and decision neuroscience.\nCurrently, I focus on developing LLM-based applications, leveraging\nmulti-agent systems and RAG frameworks to optimize workflows\nand improve AI security. At Allstate, I design and manage Lambda-\ntriggered infrastructure for real-time data processing and enhance\nLLM-powered systems with advanced evaluation frameworks and\ncontextual grounding using Guardrails.\nMy technical expertise spans machine learning (multi-pass LLM\nframeworks, RAG systems, deep learning in NLP, CV, RL),\nresponsible AI practices, and cloud infrastructure, including AWS\nservices (Lambda, S3, Bedrock, SageMaker) and serverless\narchitecture. I also specialize in backend development, including\nFastAPI/Flask API development, system architecture design, and\nDocker containerization.\nWith proven business impact, including a 5% increase in cashless\nrides and improvements in conversion prediction and loss capture\nrates, I am committed to pushing the boundaries of AI-powered\napplications and building robust security measures to defend against\nprompt injection and adversarial attacks.\nNotably, I have worked on Neural Dynamics and Disease Modeling,\nwhere I simulated Alzheimer’s disease progression and explored\nneural stability during NREM sleep. I’ve also contributed to\nconverting large-scale cortical models, ensuring compatibility and\naccuracy in simulating brain networks.\n\xa0 Page 1 of 3\xa0 \xa0\nExperience\nAllstate\nSenior Data Scientist\nJanuary 2025\xa0-\xa0Present\xa0(7 months)\nNorthern Ireland, United Kingdom\nEnkrypt AI\nAI Research Consultant\nJune 2023\xa0-\xa0September 2023\xa0(4 months)\n• Developed a malicious file scanner for python scripts and jupyter notebooks\nto enhance ML lifecycle security.\n• Built a dataset for prompt injection and backdoor attacks to fine-tune LLMs\nfor adversarial robustness.\n• Implemented demo-ready LLM security using RAGAS and NeMo GuardRails\nto counter toxicity, bias, and jailbreaks.\nGoogle Summer of Code\nOpen source, cross simulator, large scal ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I do not currently hold a patent. My expertise primarily lies in data science, artificial intelligence, and computational neuroscience, focusing on practical applications and enhancing AI technologies across various industries. If you have any other questions about my work or projects, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The agent provides a clear and honest answer, acknowledging they don't hold a patent while highlighting their areas of expertise. The response is professional and invites further questions, maintaining an engaging tone.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Passed evaluation - returning reply
# Failed evaluation - retrying
# This response is completely unacceptable. The Agent has generated a response in pig latin.
